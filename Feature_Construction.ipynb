# %% [markdown]
# <a href="https://colab.research.google.com/github/riteshkrkumarweb/Learning_AI/blob/main/Feature_Construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import seaborn as sns

from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('/content/sample_data/tested (2).csv')[['Age','Pclass','SibSp','Parch','Survived']]

# %%
df.sample(4)
# Out:
#       Age  Pclass  SibSp  Parch  Survived
# 86   27.0       3      0      0         1
# 414  39.0       1      0      0         1
# 131  53.0       1      0      0         0
# 348  24.0       2      0      0         0

# %%
df.dropna(inplace=True)

# %%
X = df.iloc[:,0:4]
y = df.iloc[:,-1]

# %%
X.sample(5)
# Out:
#       Age  Pclass  Family_type
# 254  32.5       3            0
# 8    18.0       3            0
# 171  27.0       3            0
# 412  28.0       3            0
# 66   18.0       3            0

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: Survived, dtype: int64

# %%
np.mean(cross_val_score(LogisticRegression(),X,y,scoring='accuracy',cv=25))
# Out:
# np.float64(0.6167032967032967)

# %% [markdown]
# # Apply Feature Construction

# %%
X['Family_size']= X['SibSp'] + X['Parch'] + 1

# %%
X.head()
# Out:
#     Age  Pclass  SibSp  Parch  Family_size
# 0  34.5       3      0      0            1
# 1  47.0       3      1      0            2
# 2  62.0       2      0      0            1
# 3  27.0       3      0      0            1
# 4  22.0       3      1      1            3

# %%
def myfunc(num):
  if num == 1:
    #alone
    return 0
  elif num >1 and num <=4:
    # small family
    return 1
  else:
    # large family
    return 2

# %%
myfunc(4)
# Out:
# 1

# %%
X['Family_type'] = X['Family_size'].apply(myfunc)

# %%
X.sample(5)
# Out:
#       Age  Pclass  SibSp  Parch  Family_size  Family_type
# 275  20.0       2      1      0            2            1
# 45   25.0       3      0      0            1            0
# 323  33.0       1      0      0            1            0
# 89    2.0       2      1      1            3            1
# 207  24.0       2      0      0            1            0

# %%
X.drop(columns=['SibSp','Parch','Family_size'],inplace=True)

# %%
X.head()
# Out:
#     Age  Pclass  Family_type
# 0  34.5       3            0
# 1  47.0       3            1
# 2  62.0       2            0
# 3  27.0       3            0
# 4  22.0       3            1

# %%
np.mean(cross_val_score(LogisticRegression(),X,y,scoring='accuracy',cv=5))
# Out:
# np.float64(0.617277250113071)
