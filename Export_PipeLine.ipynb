# %% [markdown]
# <a href="https://colab.research.google.com/github/riteshkrkumarweb/Learning_AI/blob/main/Export_PipeLine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np
import pandas as pd

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
test_input = np.array([3,'Male',23,12.2875 ,'Q'],dtype=object).reshape(1,5)

# %%
sample = pd.DataFrame([{
    'Pclass':3,
    "Age": 47,
    "Sex": "Femlae",
    "Fare": 7.0000,
    "Embarked": "S"
}])

# %%
pipe.predict(sample)
# Out:
# array([0])
