# %% [markdown]
# <a href="https://colab.research.google.com/github/riteshkrkumarweb/Learning_AI/blob/main/Outlier_Trimming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("/content/sample_data/bodyfat.csv", usecols=['BodyFat','Age','Weight','Height'])

# %%
df.sample(5)
# Out:
#      BodyFat  Age  Weight  Height
# 202     28.7   43  200.50   71.50
# 102     20.1   41  172.75   71.25
# 168     34.3   35  228.25   69.50
# 153     16.5   27  156.75   67.25
# 32      11.8   27  168.00   71.25

# %%
df.shape
# Out:
# (252, 4)

# %%
sns.distplot(df['BodyFat'])
# Out:
# /tmp/ipython-input-955/3173903445.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'])
# <Axes: xlabel='BodyFat', ylabel='Density'>

# %%
sns.boxplot(df['BodyFat'])
# Out:
# <Axes: ylabel='BodyFat'>

# %%
df['BodyFat'].describe()
# Out:
# count    252.000000
# mean      19.150794
# std        8.368740
# min        0.000000
# 25%       12.475000
# 50%       19.200000
# 75%       25.300000
# max       47.500000
# Name: BodyFat, dtype: float64

# %%
upper_limit = df['BodyFat'].quantile(0.99)
upper_limit
# Out:
# np.float64(36.62100000000003)

# %%
lower_limit = df['BodyFat'].quantile(0.01)
lower_limit
# Out:
# np.float64(3.357)

# %%
df[(df['BodyFat'] >= upper_limit) | (df['BodyFat'] <= lower_limit)]
# Out:
#      BodyFat  Age  Weight  Height
# 35      40.1   49  191.75   65.00
# 170      3.0   35  152.25   67.75
# 171      0.7   35  125.75   65.50
# 181      0.0   40  118.50   68.00
# 191     38.1   42  244.25   76.00
# 215     47.5   51  219.00   64.00

# %%
df[(df['BodyFat'] <= upper_limit) & (df['BodyFat'] >= lower_limit)]
# Out:
#      BodyFat  Age  Weight  Height
# 0       12.3   23  154.25   67.75
# 1        6.1   22  173.25   72.25
# 2       25.3   22  154.00   66.25
# 3       10.4   26  184.75   72.25
# 4       28.7   24  184.25   71.25
# ..       ...  ...     ...     ...
# 247     11.0   70  134.25   67.00
# 248     33.6   72  201.00   69.75
# 249     29.3   72  186.75   66.00
# 250     26.0   72  190.75   70.50
# 251     31.9   74  207.50   70.00
#
# [246 rows x 4 columns]

# %%
new_df_BodyFat = df[(df['BodyFat'] <= upper_limit) & (df['BodyFat'] >= lower_limit)]
new_df_BodyFat
# Out:
#      BodyFat  Age  Weight  Height
# 0       12.3   23  154.25   67.75
# 1        6.1   22  173.25   72.25
# 2       25.3   22  154.00   66.25
# 3       10.4   26  184.75   72.25
# 4       28.7   24  184.25   71.25
# ..       ...  ...     ...     ...
# 247     11.0   70  134.25   67.00
# 248     33.6   72  201.00   69.75
# 249     29.3   72  186.75   66.00
# 250     26.0   72  190.75   70.50
# 251     31.9   74  207.50   70.00
#
# [246 rows x 4 columns]

# %%
sns.distplot(new_df_BodyFat['BodyFat'])
# Out:
# /tmp/ipython-input-955/1043452639.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df_BodyFat['BodyFat'])
# <Axes: xlabel='BodyFat', ylabel='Density'>

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)
sns.distplot(df['BodyFat'])
plt.title('BodyFat Before Trimming ')

plt.subplot(122)
sns.distplot(new_df['BodyFat'])
plt.title('BodyFat After Trimming')

plt.show()
# Out:
# /tmp/ipython-input-955/2452144597.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BodyFat'])
# /tmp/ipython-input-955/2452144597.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['BodyFat'])

# %%
sns.distplot(df['Age'])
# Out:
# /tmp/ipython-input-163/3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.distplot(df['Weight'])
# Out:
# /tmp/ipython-input-163/1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.boxplot(df['Weight'])
# Out:
# <Axes: ylabel='Weight'>

# %%
df['Weight'].describe()
# Out:
# count    252.000000
# mean     178.924405
# std       29.389160
# min      118.500000
# 25%      159.000000
# 50%      176.500000
# 75%      197.000000
# max      363.150000
# Name: Weight, dtype: float64

# %%
upper_limit = df['Weight'].quantile(0.98)
upper_limit
# Out:
# np.float64(241.11999999999995)

# %%
lower_limit = df['Weight'].quantile(0.02)
lower_limit
# Out:
# np.float64(127.5)

# %%
new_df_Weight = df[(df['Weight'] <= upper_limit) & (df['Weight'] >= lower_limit)]
new_df_Weight
# Out:
#      BodyFat  Age  Weight  Height
# 0       12.3   23  154.25   67.75
# 1        6.1   22  173.25   72.25
# 2       25.3   22  154.00   66.25
# 3       10.4   26  184.75   72.25
# 4       28.7   24  184.25   71.25
# ..       ...  ...     ...     ...
# 247     11.0   70  134.25   67.00
# 248     33.6   72  201.00   69.75
# 249     29.3   72  186.75   66.00
# 250     26.0   72  190.75   70.50
# 251     31.9   74  207.50   70.00
#
# [241 rows x 4 columns]

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.histplot(df['Weight'],kde=True)
plt.title('Weight Before Trimming ')

plt.subplot(122)
sns.histplot(new_df_Weight['Weight'],kde=True)
plt.title('Weight After Trimming')
# Out:
# Text(0.5, 1.0, 'Weight After Trimming')

# %%
sns.distplot(df['Height'])
# Out:
# /tmp/ipython-input-955/3945773010.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
df['Height'].describe()
# Out:
# count    252.000000
# mean      70.148810
# std        3.662856
# min       29.500000
# 25%       68.250000
# 50%       70.000000
# 75%       72.250000
# max       77.750000
# Name: Height, dtype: float64

# %%
upper_limit = df['Height'].quantile(0.99)
upper_limit
# Out:
# np.float64(76.0)

# %%
lower_limit = df['Height'].quantile(0.01)
lower_limit
# Out:
# np.float64(64.3825)

# %%
new_df_Height = df[(df['Height'] <= upper_limit) & (df['Height'] >= lower_limit)]
new_df_Height
# Out:
#      BodyFat  Age  Weight  Height
# 0       12.3   23  154.25   67.75
# 1        6.1   22  173.25   72.25
# 2       25.3   22  154.00   66.25
# 3       10.4   26  184.75   72.25
# 4       28.7   24  184.25   71.25
# ..       ...  ...     ...     ...
# 247     11.0   70  134.25   67.00
# 248     33.6   72  201.00   69.75
# 249     29.3   72  186.75   66.00
# 250     26.0   72  190.75   70.50
# 251     31.9   74  207.50   70.00
#
# [247 rows x 4 columns]

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)

sns.distplot(df['Height'])
plt.title('Height Before Trimming ')

plt.subplot(122)
sns.distplot(new_df_Height['Height'])
plt.title('Height After Trimming')
# Out:
# /tmp/ipython-input-955/1369409343.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# /tmp/ipython-input-955/1369409343.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df_Height['Height'])
# Text(0.5, 1.0, 'Height After Trimming')

# %%
plt.figure(figsize=(14,8))

# BodyFat
plt.subplot(321)
sns.histplot(df['BodyFat'], kde=True)
plt.title('BodyFat Before Trimming')

plt.subplot(322)
sns.histplot(new_df_BodyFat['BodyFat'], kde=True)
plt.title('BodyFat After Trimming')

# Weight
plt.subplot(323)
sns.histplot(df['Weight'], kde=True)
plt.title('Weight Before Trimming')

plt.subplot(324)
sns.histplot(new_df_Weight['Weight'], kde=True)
plt.title('Weight After Trimming')

# Height
plt.subplot(325)
sns.histplot(df['Height'], kde=True)
plt.title('Height Before Trimming')

plt.subplot(326)
sns.histplot(new_df_Height['Height'], kde=True)
plt.title('Height After Trimming')

plt.tight_layout()
plt.show()
